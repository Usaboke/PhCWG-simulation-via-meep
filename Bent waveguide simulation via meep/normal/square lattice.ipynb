# %%
import meep as mp
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import Video
from matplotlib.patches import Polygon
import pandas as pd

# %%
from datetime import datetime

now=datetime.now()
thetime=str(now.day)+str(now.hour)+str(now.minute)
abspath='/mnt/d/Dai(COMSOL2)/meepmedia/plots/'

# %%
a = 1
r=0.24
n=12
theta=0
Bar = 8 # the barrier PhC to confine light
Ls=[20,20]# a list of the length of bent wg segments
parity=np.power(-1,len(Ls))
output_index=int((parity+1)/2) #the final waveguide may direct downwards or rightwards
Ls_temp=Ls.copy()

Pso=5
Wso=5
Pin=10
Pout=5
Wport=10

extra_N=np.abs(Pso)+3 # add some extra length and then delete it, so as to smooth the edge
Ls_temp[0]+=extra_N
Ls_temp[-1]+=extra_N

# %%
def data(Lst):  # split the x and y data stored in a nested list, thus ready for pyplot line plotting
    k = 0
    xxx = []
    yyy = []

    while k < len(Lst):
        xxx.append(Lst[k][0])
        yyy.append(Lst[k][1])

        k = k + 1
    return xxx, yyy


def distance(v1, v2):  # distance between two 2d points
    d = np.sqrt((v1[0] - v2[0]) ** 2 + (v1[1] - v2[1]) ** 2)
    return d

def moveframe(original_frame, vector):
    new_frame = []
    for var in original_frame:
        new_frame.append([var[0] + vector[0], var[1] + vector[1]])
    return new_frame

def frameX(N0, M0):
    frame = []
    for i, j in np.ndindex((N0, M0)):
        frame.append([a * i, a * j])
    return frame

def frameM(N0, M0):  # the frame
    frame = []
    for i, j in np.ndindex((N0, M0)):
        frame.append([a*np.sqrt(2) * (i+0.25)-N0*np.sqrt(2)*a/2, a*np.sqrt(2) * (j+0.25)-M0*np.sqrt(2)*a/2])
        frame.append([a*np.sqrt(2) * (i+0.75)-N0*np.sqrt(2)*a/2, a*np.sqrt(2) * (j+0.75)-M0*np.sqrt(2)*a/2])

    return frame


def polygons(r0, n0, theta0):
    polygon = []
    for i in range(n0):
        polygon.append(
            [r0 * np.sin(2 * np.pi / n0 * i + theta0 / 180 * np.pi),
             r0 * np.cos(2 * np.pi / n0 * i + theta0 / 180 * np.pi)])
    return polygon


def patterning(Frame, Polygon):  # polygons have default center (0,0). create polygon arrays on the frame.
    bulk = []
    for i in range(len(Frame)):
        on_center = Frame[i]
        New_poly = []
        for j in range(len(Polygon)):
            vertice = [sum(x) for x in zip(on_center, Polygon[j])]
            New_poly.append(vertice)
            
        bulk.append(New_poly)
    return bulk

def meepvector(point):
    result=mp.Vector3(point[0],point[1])

    return result

def meepshape(shape):
    meep_shape=[]
    for vertice in shape:
        meep_shape.append(meepvector(vertice))

    return meep_shape

def meepprism(shape,material):
    result=mp.Prism(vertices=meepshape(shape),height=mp.inf,material=material)

    return result

def meepbulk(bulk,material):
    geo=[]
    for shape in bulk:
        geo.append(meepprism(shape,material))

    return  geo


def parameter_generator(List_seg):
    global parity
    Neven = sum(List_seg[::2])
    Nodd = sum(List_seg[1::2])
    Mb=int(Nodd+Bar+(1-parity)/2*Bar)
    Nb=int(Neven+(parity+1)/2*Bar)
    Ns = sum(List_seg)
    Ms = Bar * 2
    spine_s = [[-Ns*np.sqrt(2)*a/2, 0], [Ns * a*np.sqrt(2)/2, 0]]
    spine_b = [[-Nb*np.sqrt(2)*a/2, (Mb/2-Bar) * a*np.sqrt(2)]]
    for i in range(len(List_seg)):
        parity1 = np.power(-1, i)
        new_point = spine_b[-1][:]
        new_point[int((1 - parity1) / 2)] += parity1 * List_seg[i]*a*np.sqrt(2)
        spine_b.append(new_point)
    List_s=[Ns, Ms, spine_s]
    List_b=[Nb, Mb, spine_b]
    package=[List_s,List_b]

    return package


def outside(obj,spine):
    value=1
    for point in spine:
        if obj[0]<point[0] and obj[1]<point[1]:
            value*=0
        else:
            value*=1
    return value==0


def cutblokcs(frame,spine):
    upper=[]
    lower=[]
    for point in frame:
        if outside(point,spine):
            lower.append(point)

        else:
            upper.append(point)
    return upper, lower


def cleanedge(frame,spine):
    new_frame=[]
    left=spine[0][0]+extra_N*a*np.sqrt(2)

    if len(spine)>2:
        right=spine[-1][int((parity+1)/2)]+parity*extra_N*a*np.sqrt(2)
        for point in frame:
            if point[0]>=left and (right-point[int((parity+1)/2)])*parity<=0:
                new_frame.append(point)

    else:
        right=spine[1][0]-extra_N*a*np.sqrt(2)
        for point in frame:
            if left<= point[0]<=right:
                new_frame.append(point)
    return new_frame



# try to plot a bent waveguide
def makebent(S):

    global Ls,Ls_temp
    polygon=polygons(r,n,theta)
    param_package=parameter_generator(Ls_temp)
    spines=[param_package[0][2],param_package[1][2]]
    bulk_package=[]
    for i in [0,1]:
        list_sb=param_package[i]
        NN,MM,sspine=list_sb
        fframe=frameM(NN,MM)
        upper, lower = cutblokcs(fframe, sspine)
        upper = moveframe(upper, (S * a / np.sqrt(2)/2, S * a / np.sqrt(2)/2))
        lower = moveframe(lower, (-S * a / np.sqrt(2)/2, -S * a / np.sqrt(2)/2))
        #print("origionallower=",lower[0:3])
        upper=cleanedge(upper,sspine)
        lower=cleanedge(lower,sspine)
        bulk_upper = patterning(upper, polygon)
        bulk_lower = patterning(lower, polygon)
        #print("lower=",lower[0:3])
        bulk_package.append([bulk_upper,bulk_lower])

    return bulk_package,param_package

# %%
decay="a"   # i for running till intensity decays to [check_dBm], t for fixed sim time, g for quick geometry check, a for exporting animation 
ani=bool(decay=="a")
Tvideo=300  # decay time used for making animation
n_eff = 2.7
f_input=247
check_dBm = 40
a0=500
c_const0=299792458
fcen=1000*f_input*a0/c_const0  #normalized center freq
df = 0.1
nfreq = 500 # number of frequencies at which to compute flux
dpml=1
parameterS=2.5


resolution = 16
eps=n_eff**2
eps2=1  # sometimes the input wire is not needed, set its eps to 1.

# %%
def phc_trans(wgtype=0, T_decay=1000):   #wgtype=0 for straight wg, 1 for bent wg, 0.1 for free space but skips the animation code, 0.2 for free space as well but can output mode evolution.mp4

    bulk_package,params=makebent(parameterS)
    print("all is fine here")

    def meepports():
    
        port_package=[]
        for i in [0,1]:
            spine=params[i][2]
            left=spine[0][0]+extra_N*np.sqrt(2)*a
            source=[mp.Source(mp.GaussianSource(fcen, fwidth=df),
                              component=mp.Ez,
                              center=mp.Vector3(left-Pso*np.sqrt(2),spine[0][1]),
                              size=mp.Vector3(0,Wso))]

            port1=mp.FluxRegion(center=mp.Vector3(left+Pin*np.sqrt(2),spine[0][1]),size=mp.Vector3(0,Wport))
            decay_check=mp.Vector3(spine[-1][0]+(extra_N+Pin)*np.sqrt(2)*(((1-output_index)*parity)*i+(i-1)),spine[-1][1]+i*(extra_N+Pin)*np.sqrt(2)*(output_index)*parity)
            port2=mp.FluxRegion(center=decay_check,size=mp.Vector3(Wport*output_index*i,Wport*(1-i*output_index)))

            ports_by_wg=[source,port1,port2,decay_check]
            port_package.append(ports_by_wg)  #index 0 fr str, index 1 for bent
        return port_package

    def sizes():
        return [params[0][i]*a*np.sqrt(2) for i in [0,1]],[params[1][i]*a*np.sqrt(2) for i in [0,1]]


    cell=mp.Vector3(sizes()[int(wgtype)][0],sizes()[int(wgtype)][1],0)
    if wgtype==0.1:
        geometry = []   
    else:
        geometry=meepbulk(sum(bulk_package[int(wgtype)],[]),mp.Medium(epsilon=eps))

        #print(sum(bulk_package[int(wgtype)],[]))
    #waveguide = mp.Block(mp.Vector3(mp.inf,ww,mp.inf),center=mp.Vector3(0,0,0),material=mp.Medium(epsilon=eps))
    
    
    pml_layers = [mp.PML(dpml)]

    source,port1,port2,decay_check=meepports()[int(wgtype)]
    sim = mp.Simulation(cell_size=cell,
                        boundary_layers=pml_layers,
                        geometry=geometry,
                        sources=source,
                        resolution=resolution)

    fluxes=[sim.add_flux(fcen, df, nfreq, port) for port in [port1,port2]]

    if ani and wgtype in [0,1,0.2]:
        f = plt.figure(dpi=150)
        Animate = mp.Animate2D(sim, fields=mp.Ez, f=f,
                               #field_parameters={'alpha':0.8, 'cmap':'RdBu', 'interpolation':'none'},
                               realtime=False, normalize=True)

        sim.run(mp.at_every(0.25,Animate),until=Tvideo)

        plt.close()

        filename1 = thetime+"_"+str(wgtype)+'_freq='+str(f_input)+'_T='+str(Tvideo)
        filename2 = '/mnt/d/Dai(COMSOL2)/meepmedia/video2/'+filename1
        filename = filename2+".mp4"
        fps = 60
        Animate.to_mp4(fps,filename)
        Video(filename)
    else:

        # show geometry
        # %matplotlib inline
        f = plt.figure(dpi=150)
        sim.plot2D(ax=f.gca())

        filename=abspath+thetime+"wg="+str(wgtype)
        if decay in ["i","t"]:
            plt.savefig(filename+".jpg")
        plt.show()
        
        if decay=="i":
            sim.run(until_after_sources=mp.stop_when_fields_decayed(100, mp.Ez, decay_check, pow(10,-check_dBm/10)))
            #plt.savefig(filename+".jpg")
        elif decay=="t":
            sim.run(until=T_decay)
            #plt.savefig(filename+".jpg")
        elif decay=="g":
            sim.run(until=1)

    results = [mp.get_flux_freqs(fluxes[-1])]
    for var in fluxes:
        results.append(mp.get_fluxes(var))

    return results

# %%
result_none=phc_trans(wgtype=0.1)  # only ports and free space
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# all is fine here
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000237942 s
# Working in 2D dimensions.
# Computational cell is 79.1875 x 22.625 x 0 with resolution 16
# time for set_epsilon = 0.605326 s
# -----------
# Meep progress: 10.1875/200.0 = 5.1% done in 4.0s, 74.6s to go
# on time step 326 (time=10.1875), 0.0122776 s/step
# Meep progress: 28.1875/200.0 = 14.1% done in 8.0s, 48.8s to go
# on time step 902 (time=28.1875), 0.00694658 s/step
# Meep progress: 44.0/200.0 = 22.0% done in 12.0s, 42.6s to go
# on time step 1408 (time=44), 0.00790862 s/step
# Meep progress: 61.25/200.0 = 30.6% done in 16.0s, 36.3s to go
# on time step 1960 (time=61.25), 0.00726401 s/step
# Meep progress: 78.84375/200.0 = 39.4% done in 20.0s, 30.8s to go
# on time step 2524 (time=78.875), 0.00709851 s/step
# Meep progress: 95.90625/200.0 = 48.0% done in 24.0s, 26.1s to go
# on time step 3070 (time=95.9375), 0.00733068 s/step
# Meep progress: 113.25/200.0 = 56.6% done in 28.1s, 21.5s to go
# on time step 3624 (time=113.25), 0.00726215 s/step
# Meep progress: 130.125/200.0 = 65.1% done in 32.1s, 17.2s to go
# on time step 4164 (time=130.125), 0.00740804 s/step
# Meep progress: 147.9375/200.0 = 74.0% done in 36.1s, 12.7s to go
# on time step 4734 (time=147.938), 0.0070198 s/step
# Meep progress: 166.15625/200.0 = 83.1% done in 40.1s, 8.2s to go
# on time step 5317 (time=166.156), 0.00686609 s/step
# Meep progress: 184.0/200.0 = 92.0% done in 44.1s, 3.8s to go
# on time step 5888 (time=184), 0.00704723 s/step
# Normalizing field data...
# run 0 finished at t = 200.0 (6400 timesteps)
# Generating MP4...

# %%
result_str=phc_trans(wgtype=0,T_decay=2000)
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# all is fine here
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.989056 s
# Working in 2D dimensions.
# Computational cell is 79.1875 x 22.625 x 0 with resolution 16
#      prism, center = (-27.7539,1.94454,5e+19)
#           height 1e+20, axis (0,0,1), sidewall angle: 0 radians, 12 vertices:
#           (-27.7539,2.18454,0)
#           (-27.6339,2.15239,0)
#           (-27.5461,2.06454,0)
#           (-27.5139,1.94454,0)
#           (-27.5461,1.82454,0)
#           (-27.6339,1.7367,0)
#           (-27.7539,1.70454,0)
#           (-27.8739,1.7367,0)
#           (-27.9618,1.82454,0)
#           (-27.9939,1.94454,0)
#           (-27.9618,2.06454,0)
#           (-27.8739,2.15239,0)
#           dielectric constant epsilon diagonal = (7.29,7.29,7.29)
#      prism, center = (-27.7539,3.35876,5e+19)
#           height 1e+20, axis (0,0,1), sidewall angle: 0 radians, 12 vertices:
#           (-27.7539,3.59876,0)
#           (-27.6339,3.5666,0)
#           (-27.5461,3.47876,0)
#           (-27.5139,3.35876,0)
#           (-27.5461,3.23876,0)
#           (-27.6339,3.15091,0)
#           (-27.7539,3.11876,0)
#           (-27.8739,3.15091,0)
#           (-27.9618,3.23876,0)
#           (-27.9939,3.35876,0)
#           (-27.9618,3.47876,0)
#           (-27.8739,3.5666,0)
#           dielectric constant epsilon diagonal = (7.29,7.29,7.29)
#      prism, center = (-27.7539,4.77297,5e+19)
#           height 1e+20, axis (0,0,1), sidewall angle: 0 radians, 12 vertices:
#           (-27.7539,5.01297,0)
#           (-27.6339,4.98082,0)
#           (-27.5461,4.89297,0)
#           (-27.5139,4.77297,0)
#           (-27.5461,4.65297,0)
#           (-27.6339,4.56512,0)
#           (-27.7539,4.53297,0)
#           (-27.8739,4.56512,0)
#           (-27.9618,4.65297,0)
#           (-27.9939,4.77297,0)
#           (-27.9618,4.89297,0)
#           (-27.8739,4.98082,0)
#           dielectric constant epsilon diagonal = (7.29,7.29,7.29)
#      prism, center = (-27.7539,6.18718,5e+19)
#           height 1e+20, axis (0,0,1), sidewall angle: 0 radians, 12 vertices:
#           (-27.7539,6.42718,0)
#           (-27.6339,6.39503,0)
#           (-27.5461,6.30718,0)
#           (-27.5139,6.18718,0)
#           (-27.5461,6.06718,0)
#           (-27.6339,5.97934,0)
#           (-27.7539,5.94718,0)
#           (-27.8739,5.97934,0)
#           (-27.9618,6.06718,0)
#           (-27.9939,6.18718,0)
#           (-27.9618,6.30718,0)
#           (-27.8739,6.39503,0)
#           dielectric constant epsilon diagonal = (7.29,7.29,7.29)
#      prism, center = (-27.7539,7.6014,5e+19)
#           height 1e+20, axis (0,0,1), sidewall angle: 0 radians, 12 vertices:
#           (-27.7539,7.8414,0)
#           (-27.6339,7.80924,0)
#           (-27.5461,7.7214,0)
#           (-27.5139,7.6014,0)
#           (-27.5461,7.4814,0)
#           (-27.6339,7.39355,0)
#           (-27.7539,7.3614,0)
#           (-27.8739,7.39355,0)
#           (-27.9618,7.4814,0)
#           (-27.9939,7.6014,0)
#           (-27.9618,7.7214,0)
#           (-27.8739,7.80924,0)
#           dielectric constant epsilon diagonal = (7.29,7.29,7.29)
#      prism, center = (-27.7539,9.01561,5e+19)
#           height 1e+20, axis (0,0,1), sidewall angle: 0 radians, 12 vertices:
#           (-27.7539,9.25561,0)
#           (-27.6339,9.22346,0)
#           (-27.5461,9.13561,0)
#           (-27.5139,9.01561,0)
#           (-27.5461,8.89561,0)
#           (-27.6339,8.80777,0)
#           (-27.7539,8.77561,0)
#           (-27.8739,8.80777,0)
#           (-27.9618,8.89561,0)
#           (-27.9939,9.01561,0)
#           (-27.9618,9.13561,0)
#           (-27.8739,9.22346,0)
#           dielectric constant epsilon diagonal = (7.29,7.29,7.29)
#      prism, center = (-27.7539,10.4298,5e+19)
#           height 1e+20, axis (0,0,1), sidewall angle: 0 radians, 12 vertices:
#           (-27.7539,10.6698,0)
#           (-27.6339,10.6377,0)
#           (-27.5461,10.5498,0)
#           (-27.5139,10.4298,0)
#           (-27.5461,10.3098,0)
#           (-27.6339,10.222,0)
#           (-27.7539,10.1898,0)
#           (-27.8739,10.222,0)
#           (-27.9618,10.3098,0)
#           (-27.9939,10.4298,0)
#           (-27.9618,10.5498,0)
#           (-27.8739,10.6377,0)
#           dielectric constant epsilon diagonal = (7.29,7.29,7.29)
#      prism, center = (-27.7539,11.844,5e+19)
#           height 1e+20, axis (0,0,1), sidewall angle: 0 radians, 12 vertices:
#           (-27.7539,12.084,0)
#           (-27.6339,12.0519,0)
#           (-27.5461,11.964,0)
#           (-27.5139,11.844,0)
#           (-27.5461,11.724,0)
#           (-27.6339,11.6362,0)
#           (-27.7539,11.604,0)
#           (-27.8739,11.6362,0)
#           (-27.9618,11.724,0)
#           (-27.9939,11.844,0)
#           (-27.9618,11.964,0)
#           (-27.8739,12.0519,0)
#           dielectric constant epsilon diagonal = (7.29,7.29,7.29)
#      prism, center = (-27.0468,1.23744,5e+19)
#           height 1e+20, axis (0,0,1), sidewall angle: 0 radians, 12 vertices:
#           (-27.0468,1.47744,0)
#           (-26.9268,1.44528,0)
#           (-26.839,1.35744,0)
#           (-26.8068,1.23744,0)
#           (-26.839,1.11744,0)
#           (-26.9268,1.02959,0)
#           (-27.0468,0.997437,0)
#           (-27.1668,1.02959,0)
#           (-27.2547,1.11744,0)
#           (-27.2868,1.23744,0)
#           (-27.2547,1.35744,0)
#           (-27.1668,1.44528,0)
#           dielectric constant epsilon diagonal = (7.29,7.29,7.29)
#      prism, center = (-26.3397,1.94454,5e+19)
#           height 1e+20, axis (0,0,1), sidewall angle: 0 radians, 12 vertices:
#           (-26.3397,2.18454,0)
#           (-26.2197,2.15239,0)
#           (-26.1319,2.06454,0)
#           (-26.0997,1.94454,0)
#           (-26.1319,1.82454,0)
#           (-26.2197,1.7367,0)
#           (-26.3397,1.70454,0)
#           (-26.4597,1.7367,0)
#           (-26.5476,1.82454,0)
#           (-26.5797,1.94454,0)
#           (-26.5476,2.06454,0)
#           (-26.4597,2.15239,0)
#           dielectric constant epsilon diagonal = (7.29,7.29,7.29)
#      ...(+ 1270 objects not shown)...
# subpixel-averaging is 30.0501% done, 9.40498 s remaining
# subpixel-averaging is 48.031% done, 4.33663 s remaining
# subpixel-averaging is 66.0119% done, 2.06649 s remaining
# subpixel-averaging is 83.7465% done, 0.784058 s remaining
# subpixel-averaging is 31.2816% done, 8.90416 s remaining
# subpixel-averaging is 49.7552% done, 4.06825 s remaining
# subpixel-averaging is 67.7361% done, 1.91345 s remaining
# subpixel-averaging is 85.4707% done, 0.681881 s remaining
# subpixel-averaging is 31.5279% done, 8.73826 s remaining
# subpixel-averaging is 49.5089% done, 4.08659 s remaining
# subpixel-averaging is 67.9824% done, 1.89676 s remaining
# subpixel-averaging is 85.9633% done, 0.66028 s remaining
# time for set_epsilon = 56.1238 s
# -----------
# Meep progress: 14.96875/200.0 = 7.5% done in 4.0s, 49.4s to go
# on time step 479 (time=14.9688), 0.00835141 s/step
# Meep progress: 36.25/200.0 = 18.1% done in 8.0s, 36.2s to go
# on time step 1160 (time=36.25), 0.00587939 s/step
# Meep progress: 58.25/200.0 = 29.1% done in 12.0s, 29.2s to go
# on time step 1865 (time=58.2812), 0.00567827 s/step
# Meep progress: 82.75/200.0 = 41.4% done in 16.0s, 22.7s to go
# on time step 2648 (time=82.75), 0.00511204 s/step
# Meep progress: 106.75/200.0 = 53.4% done in 20.0s, 17.5s to go
# on time step 3416 (time=106.75), 0.00523428 s/step
# Meep progress: 130.5/200.0 = 65.2% done in 24.0s, 12.8s to go
# on time step 4176 (time=130.5), 0.00527343 s/step
# Meep progress: 155.25/200.0 = 77.6% done in 28.1s, 8.1s to go
# on time step 4968 (time=155.25), 0.00506281 s/step
# Meep progress: 179.25/200.0 = 89.6% done in 32.1s, 3.7s to go
# on time step 5736 (time=179.25), 0.00522804 s/step
# Normalizing field data...
# run 0 finished at t = 200.0 (6400 timesteps)
# Generating MP4...

# %%
result_bent=phc_trans(wgtype=1,T_decay=3000)
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# all is fine here
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.3042 s
# Working in 2D dimensions.
# Computational cell is 50.9375 x 50.9375 x 0 with resolution 16
#      prism, center = (-13.6118,16.0867,5e+19)
#           height 1e+20, axis (0,0,1), sidewall angle: 0 radians, 12 vertices:
#           (-13.6118,16.3267,0)
#           (-13.4918,16.2945,0)
#           (-13.404,16.2067,0)
#           (-13.3718,16.0867,0)
#           (-13.404,15.9667,0)
#           (-13.4918,15.8788,0)
#           (-13.6118,15.8467,0)
#           (-13.7318,15.8788,0)
#           (-13.8197,15.9667,0)
#           (-13.8518,16.0867,0)
#           (-13.8197,16.2067,0)
#           (-13.7318,16.2945,0)
#           dielectric constant epsilon diagonal = (7.29,7.29,7.29)
#      prism, center = (-13.6118,17.5009,5e+19)
#           height 1e+20, axis (0,0,1), sidewall angle: 0 radians, 12 vertices:
#           (-13.6118,17.7409,0)
#           (-13.4918,17.7087,0)
#           (-13.404,17.6209,0)
#           (-13.3718,17.5009,0)
#           (-13.404,17.3809,0)
#           (-13.4918,17.293,0)
#           (-13.6118,17.2609,0)
#           (-13.7318,17.293,0)
#           (-13.8197,17.3809,0)
#           (-13.8518,17.5009,0)
#           (-13.8197,17.6209,0)
#           (-13.7318,17.7087,0)
#           dielectric constant epsilon diagonal = (7.29,7.29,7.29)
#      prism, center = (-13.6118,18.9151,5e+19)
#           height 1e+20, axis (0,0,1), sidewall angle: 0 radians, 12 vertices:
#           (-13.6118,19.1551,0)
#           (-13.4918,19.123,0)
#           (-13.404,19.0351,0)
#           (-13.3718,18.9151,0)
#           (-13.404,18.7951,0)
#           (-13.4918,18.7073,0)
#           (-13.6118,18.6751,0)
#           (-13.7318,18.7073,0)
#           (-13.8197,18.7951,0)
#           (-13.8518,18.9151,0)
#           (-13.8197,19.0351,0)
#           (-13.7318,19.123,0)
#           dielectric constant epsilon diagonal = (7.29,7.29,7.29)
#      prism, center = (-13.6118,20.3293,5e+19)
#           height 1e+20, axis (0,0,1), sidewall angle: 0 radians, 12 vertices:
#           (-13.6118,20.5693,0)
#           (-13.4918,20.5372,0)
#           (-13.404,20.4493,0)
#           (-13.3718,20.3293,0)
#           (-13.404,20.2093,0)
#           (-13.4918,20.1215,0)
#           (-13.6118,20.0893,0)
#           (-13.7318,20.1215,0)
#           (-13.8197,20.2093,0)
#           (-13.8518,20.3293,0)
#           (-13.8197,20.4493,0)
#           (-13.7318,20.5372,0)
#           dielectric constant epsilon diagonal = (7.29,7.29,7.29)
#      prism, center = (-13.6118,21.7435,5e+19)
#           height 1e+20, axis (0,0,1), sidewall angle: 0 radians, 12 vertices:
#           (-13.6118,21.9835,0)
#           (-13.4918,21.9514,0)
#           (-13.404,21.8635,0)
#           (-13.3718,21.7435,0)
#           (-13.404,21.6235,0)
#           (-13.4918,21.5357,0)
#           (-13.6118,21.5035,0)
#           (-13.7318,21.5357,0)
#           (-13.8197,21.6235,0)
#           (-13.8518,21.7435,0)
#           (-13.8197,21.8635,0)
#           (-13.7318,21.9514,0)
#           dielectric constant epsilon diagonal = (7.29,7.29,7.29)
#      prism, center = (-13.6118,23.1577,5e+19)
#           height 1e+20, axis (0,0,1), sidewall angle: 0 radians, 12 vertices:
#           (-13.6118,23.3977,0)
#           (-13.4918,23.3656,0)
#           (-13.404,23.2777,0)
#           (-13.3718,23.1577,0)
#           (-13.404,23.0377,0)
#           (-13.4918,22.9499,0)
#           (-13.6118,22.9177,0)
#           (-13.7318,22.9499,0)
#           (-13.8197,23.0377,0)
#           (-13.8518,23.1577,0)
#           (-13.8197,23.2777,0)
#           (-13.7318,23.3656,0)
#           dielectric constant epsilon diagonal = (7.29,7.29,7.29)
#      prism, center = (-13.6118,24.572,5e+19)
#           height 1e+20, axis (0,0,1), sidewall angle: 0 radians, 12 vertices:
#           (-13.6118,24.812,0)
#           (-13.4918,24.7798,0)
#           (-13.404,24.692,0)
#           (-13.3718,24.572,0)
#           (-13.404,24.452,0)
#           (-13.4918,24.3641,0)
#           (-13.6118,24.332,0)
#           (-13.7318,24.3641,0)
#           (-13.8197,24.452,0)
#           (-13.8518,24.572,0)
#           (-13.8197,24.692,0)
#           (-13.7318,24.7798,0)
#           dielectric constant epsilon diagonal = (7.29,7.29,7.29)
#      prism, center = (-13.6118,25.9862,5e+19)
#           height 1e+20, axis (0,0,1), sidewall angle: 0 radians, 12 vertices:
#           (-13.6118,26.2262,0)
#           (-13.4918,26.194,0)
#           (-13.404,26.1062,0)
#           (-13.3718,25.9862,0)
#           (-13.404,25.8662,0)
#           (-13.4918,25.7783,0)
#           (-13.6118,25.7462,0)
#           (-13.7318,25.7783,0)
#           (-13.8197,25.8662,0)
#           (-13.8518,25.9862,0)
#           (-13.8197,26.1062,0)
#           (-13.7318,26.194,0)
#           dielectric constant epsilon diagonal = (7.29,7.29,7.29)
#      prism, center = (-12.9047,15.3796,5e+19)
#           height 1e+20, axis (0,0,1), sidewall angle: 0 radians, 12 vertices:
#           (-12.9047,15.6196,0)
#           (-12.7847,15.5874,0)
#           (-12.6969,15.4996,0)
#           (-12.6647,15.3796,0)
#           (-12.6969,15.2596,0)
#           (-12.7847,15.1717,0)
#           (-12.9047,15.1396,0)
#           (-13.0247,15.1717,0)
#           (-13.1125,15.2596,0)
#           (-13.1447,15.3796,0)
#           (-13.1125,15.4996,0)
#           (-13.0247,15.5874,0)
#           dielectric constant epsilon diagonal = (7.29,7.29,7.29)
#      prism, center = (-12.1976,16.0867,5e+19)
#           height 1e+20, axis (0,0,1), sidewall angle: 0 radians, 12 vertices:
#           (-12.1976,16.3267,0)
#           (-12.0776,16.2945,0)
#           (-11.9897,16.2067,0)
#           (-11.9576,16.0867,0)
#           (-11.9897,15.9667,0)
#           (-12.0776,15.8788,0)
#           (-12.1976,15.8467,0)
#           (-12.3176,15.8788,0)
#           (-12.4054,15.9667,0)
#           (-12.4376,16.0867,0)
#           (-12.4054,16.2067,0)
#           (-12.3176,16.2945,0)
#           dielectric constant epsilon diagonal = (7.29,7.29,7.29)
#      ...(+ 1535 objects not shown)...
# subpixel-averaging is 33.1956% done, 8.05466 s remaining
# subpixel-averaging is 46.7682% done, 4.57393 s remaining
# subpixel-averaging is 59.6868% done, 2.70263 s remaining
# subpixel-averaging is 72.2783% done, 1.53939 s remaining
# subpixel-averaging is 87.6497% done, 0.570106 s remaining
# subpixel-averaging is 99.26% done, 0.0298896 s remaining
# subpixel-averaging is 33.3591% done, 8.10139 s remaining
# subpixel-averaging is 46.7682% done, 4.56313 s remaining
# subpixel-averaging is 60.3409% done, 2.64014 s remaining
# subpixel-averaging is 73.423% done, 1.45042 s remaining
# subpixel-averaging is 88.6309% done, 0.518576 s remaining
# subpixel-averaging is 33.6862% done, 7.9126 s remaining
# subpixel-averaging is 46.6047% done, 4.5834 s remaining
# subpixel-averaging is 59.6868% done, 2.70759 s remaining
# subpixel-averaging is 72.6053% done, 1.53349 s remaining
# subpixel-averaging is 88.4673% done, 0.522856 s remaining
# time for set_epsilon = 77.5401 s
# -----------
# Meep progress: 5.75/300.0 = 1.9% done in 4.0s, 205.8s to go
# on time step 184 (time=5.75), 0.0218542 s/step
# Meep progress: 19.40625/300.0 = 6.5% done in 8.0s, 116.0s to go
# on time step 621 (time=19.4062), 0.00916016 s/step
# Meep progress: 33.34375/300.0 = 11.1% done in 12.0s, 96.2s to go
# on time step 1067 (time=33.3438), 0.00897265 s/step
# Meep progress: 47.28125/300.0 = 15.8% done in 16.0s, 85.7s to go
# on time step 1513 (time=47.2812), 0.00896985 s/step
# Meep progress: 61.40625/300.0 = 20.5% done in 20.0s, 77.8s to go
# on time step 1965 (time=61.4062), 0.00885033 s/step
# Meep progress: 75.5/300.0 = 25.2% done in 24.0s, 71.5s to go
# on time step 2416 (time=75.5), 0.00886953 s/step
# Meep progress: 90.0/300.0 = 30.0% done in 28.0s, 65.4s to go
# on time step 2880 (time=90), 0.00865252 s/step
# Meep progress: 104.25/300.0 = 34.8% done in 32.1s, 60.2s to go
# on time step 3336 (time=104.25), 0.00882706 s/step
# Meep progress: 118.0/300.0 = 39.3% done in 36.1s, 55.7s to go
# on time step 3776 (time=118), 0.00910541 s/step
# Meep progress: 131.0625/300.0 = 43.7% done in 40.1s, 51.7s to go
# on time step 4194 (time=131.062), 0.00957162 s/step
# Meep progress: 144.34375/300.0 = 48.1% done in 44.1s, 47.5s to go
# on time step 4619 (time=144.344), 0.00941812 s/step
# Meep progress: 158.25/300.0 = 52.8% done in 48.1s, 43.1s to go
# on time step 5064 (time=158.25), 0.00903802 s/step
# Meep progress: 172.34375/300.0 = 57.4% done in 52.1s, 38.6s to go
# on time step 5516 (time=172.375), 0.00885798 s/step
# Meep progress: 186.5625/300.0 = 62.2% done in 56.1s, 34.1s to go
# on time step 5971 (time=186.594), 0.00879663 s/step
# Meep progress: 200.75/300.0 = 66.9% done in 60.1s, 29.7s to go
# on time step 6424 (time=200.75), 0.00887705 s/step
# Meep progress: 214.5/300.0 = 71.5% done in 64.2s, 25.6s to go
# on time step 6864 (time=214.5), 0.0091125 s/step
# Meep progress: 227.8125/300.0 = 75.9% done in 68.2s, 21.6s to go
# on time step 7290 (time=227.812), 0.00939709 s/step
# Meep progress: 240.75/300.0 = 80.2% done in 72.2s, 17.8s to go
# on time step 7704 (time=240.75), 0.00967209 s/step
# Meep progress: 253.9375/300.0 = 84.6% done in 76.2s, 13.8s to go
# on time step 8126 (time=253.938), 0.00948749 s/step
# Meep progress: 267.28125/300.0 = 89.1% done in 80.2s, 9.8s to go
# on time step 8553 (time=267.281), 0.00937824 s/step
# Meep progress: 280.75/300.0 = 93.6% done in 84.2s, 5.8s to go
# on time step 8984 (time=280.75), 0.00931108 s/step
# Meep progress: 294.25/300.0 = 98.1% done in 88.2s, 1.7s to go
# on time step 9416 (time=294.25), 0.00936838 s/step
# Normalizing field data...

# %%
def sortports(result):
    result_array=np.array(result)
    f,p1,p2=result_array
    return f,p1,p2

abspath='/mnt/d/Dai(COMSOL2)/meepmedia/plots/'

# %%
try:
    fig, ax = plt.subplots()
    f,p1_none,p2_none=sortports(result_none)
    freqs=c_const0 * np.array(f)/a0/1000
    ax.plot(freqs,p1_none,label="p1")
    ax.plot(freqs,p2_none,label="p2")
    plt.legend(fontsize=20)
    if decay in ["t","i"]:    
        plt.savefig(abspath+thetime+"none.png")
    #plt.ylim([0,1.2])
except Exception as e: print(e)

# %%
try:
    fig, ax = plt.subplots()
    f,p1_str,p2_str=sortports(result_str)
    couplingE=p1_str/p1_none
    freqs=c_const0 * np.array(f)/a0/1000
    ax.plot(freqs,couplingE,label="Coupling Efficiency")
    #ax.plot(freqs,p2_str,label="p2")
    plt.legend(fontsize=20)
    if decay in ["t","i"]:    
        plt.savefig(abspath+thetime+"CE.png")
    #plt.ylim([0,1.2])
except Exception as e: print(e)

# %%
try:
    fig, ax = plt.subplots()
    f,p1_bent,p2_bent=sortports(result_bent)
    if parity==1:
        p2_bent=[element*-1 for element in p2_bent]

    T_str=p2_str/p1_str
    T_bent=p2_bent/p1_str
    freqs=c_const0 * np.array(f)/a0/1000
    ax.plot(freqs,T_str,label="Str")
    ax.plot(freqs,T_bent,label="Bent")
    plt.legend(fontsize=20)
    plt.ylim([0,1.2])
    if decay in ["t","i"]:    
        plt.savefig(abspath+thetime+"_S="+str(parameterS)+"_T-spectra.png")

except Exception as e: print(e)

# %%
if decay in ["i","t"]:
    dff = pd.DataFrame()
    dff["freq"] = freqs
    dff["Coupling Efficiency"] = couplingE
    dff["Str"] = T_str
    dff["Bent"]=T_bent
    dff.to_csv(abspath+thetime+"S="+str(parameterS)+".csv", index=False)
